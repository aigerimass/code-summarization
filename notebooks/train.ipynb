# %%
# !git clone https://github.com/aigerimass/code-summarization.git
# Out:
# Cloning into 'code-summarization'...
# remote: Enumerating objects: 210, done.
# remote: Counting objects: 100% (210/210), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 210 (delta 101), reused 160 (delta 56), pack-reused 0
# Receiving objects: 100% (210/210), 161.74 KiB | 2.10 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#   inflating: __MACOSX/._dataset
#   inflating: __MACOSX/dataset/._python
# replace dataset/preprocess.py? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !mv /content/drive/MyDrive/dataset.zip /content/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install poetry
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 29.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.6/306.6 kB 32.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 37.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 106.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 50.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.0.0
#     Uninstalling platformdirs-4.0.0:
#       Successfully uninstalled platformdirs-4.0.0
#   Attempting uninstall: keyring
# ...

# %%
import os
os.chdir("/content/code-summarization")

# %%
# !poetry config virtualenvs.in-project false

# %%
# !poetry install
# Out:
# Streaming output truncated to the last 5000 lines.
#   • Installing decorator (5.1.1): Downloading... 0%
#   • Installing jedi (0.19.1): Pending...
#   • Installing argon2-cffi (23.1.0): Installing...
#   • Installing certifi (2023.11.17): Downloading... 0%
#   • Installing charset-normalizer (3.3.2): Pending...
#   • Installing decorator (5.1.1): Downloading... 0%
#   • Installing jedi (0.19.1): Pending...
#   • Installing jedi (0.19.1): Pending...
#   • Installing decorator (5.1.1): Downloading... 100%
#   • Installing jedi (0.19.1): Pending...
#   • Installing jedi (0.19.1): Pending...
#   • Installing decorator (5.1.1): Installing...
#   • Installing jedi (0.19.1): Pending...
#   • Installing argon2-cffi (23.1.0): Installing...
#   • Installing certifi (2023.11.17): Downloading... 0%
#   • Installing charset-normalizer (3.3.2): Pending...
#   • Installing decorator (5.1.1): Installing...
#   • Installing jedi (0.19.1): Pending...
# ...

# %%
# !poetry run wandb login 5b10d03c74785aec0b48880dc78dcc4cbce32fa7
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !poetry run unixcoder-train
# Out:
# [2023-12-04 16:40:26,472][unixcoder_pipeline.training.run][INFO] - device: cuda, n_gpu: 1
# [2023-12-04 16:40:29,247][unixcoder_pipeline.training.run][INFO] - Training/evaluation parameters {'do_train': True, 'do_eval': True, 'seed': 42, 'model_name_or_path': 'microsoft/unixcoder-base', 'train_filename': 'dataset/python/train.jsonl', 'dev_filename': 'dataset/python/valid.jsonl', 'test_filename': None, 'output_dir': 'saved_models/python', 'max_source_length': 256, 'max_target_length': 128, 'beam_size': 10, 'n_gpu': 1, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'max_grad_norm': 1.0, 'train_batch_size': 48, 'eval_batch_size': 48, 'learning_rate': 0.0001, 'gradient_accumulation_steps': 2, 'num_train_epochs': 3}
# wandb: Currently logged in as: n8ron22. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.0
# wandb: Run data is saved locally in /content/code-summarization/wandb/run-20231204_164031-780r3xym
# ...

# %%
# !chmod +x src/training/run.py

# %%
# !poetry run python3 src/training/run.py
# Out:
# Traceback (most recent call last):
#   File "/content/code-summarization/src/training/run.py", line 30, in <module>
#     from src.data_processing.process_features import read_examples, convert_examples_to_features, Example
# ModuleNotFoundError: No module named 'src'
